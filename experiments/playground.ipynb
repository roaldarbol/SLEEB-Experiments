# %%
import time
import sys
sys.path.append('..')
from belay import Device, list_devices, UsbSpecifier
from devices.PicoBonn import PicoBonn
from devices.PicoBonnAction import PicoBonnAction

# %%
list_devices()
# Out:
# [UsbSpecifier(vid=11914, pid=5, serial_number='135C518948D82F8B', manufacturer='Microsoft', location='1-7.4:x.0')]

# %%
spec = UsbSpecifier(vid=11914, pid=5, serial_number='135C518948D82F8B', manufacturer='Microsoft', location='1-7.4:x.0')

# %%
pico = PicoBonn(spec)
# Out:
# ---------------------------------------------------------------------------
#
# PyboardException                          Traceback (most recent call last)
#
# Cell In[4], line 1
#
# ----> 1 pico = PicoBonn(spec)
#
#
#
# File ~\Projects\BelayExperiments\.venv\Lib\site-packages\belay\device.py:277, in Device.__init__(self, startup, attempts, auto_sync_time, *args, **kwargs)
#
#     274 self.__pre_autoinit__()
#
#     276 for executer in sort_executers(autoinit_executers):
#
# --> 277     executer()
#
#     279 atexit.register(self.close)
#
#     281 self.__post_init__()
#
#
#
# File ~\Projects\BelayExperiments\.venv\Lib\site-packages\belay\executers.py:82, in _GlobalExecuter.__call__.<locals>.executer(*args, **kwargs)
#
#      79     cmd = arg_assign_cmd + "\n" + cmd
#
#      81 try:
#
# ---> 82     self._belay_device._traceback_execute(src_file, src_lineno, name, cmd, record=record)
#
#      83 except Exception:
#
#      84     if not ignore_errors:
#
#
#
# ...

# %%
pico.rainbow_cycle(10, 1)       # Rotating rainbow, 3 cycles, 50ms delay
pico.clear_neopixels()          # Turn off when done

# %%
pico.set_all_neopixels(50,20,20)

# %%
pico.fan_off()

# %%
pico.close()
